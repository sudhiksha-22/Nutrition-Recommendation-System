# %%
import pandas as pd 
import numpy as np
import warnings
import time
import seaborn as sns
import matplotlib.pyplot as plt
import random
import nltk
from nltk.corpus import stopwords

warnings.filterwarnings('ignore')

# %%
class Profile:
    
    df = pd.read_csv('dataset.csv') # static variable
    
    def __init__(self,diet,disease,Nutrient,food_type,favorite_food):
        self.diet = diet
        self.disease = disease
        self.nutrient = Nutrient
        self.type = food_type
        self.like = favorite_food
        self.df2 = pd.DataFrame(columns=list(Profile.df.columns)) #filtered based on nutrient and veg_nv
        self.df3 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df4 = pd.DataFrame(columns=list(Profile.df.columns)) #based on diet plan
        self.df5 = pd.DataFrame(columns=list(Profile.df.columns)) #based on disease
        self.df6 = pd.DataFrame(columns=list(Profile.df.columns)) #based on food and category
        
    def removestop(self,tokens):
        stop = set(stopwords.words('english'))
        file = open('stopwords.txt','r')
        l = list(file.read().split())
        stop = list(stop) +l
        l = [token for token in tokens if token not in stop]
        return l
            
    def inputs(self,diet,disease,Nutrient,food_type,favorite_food):
        
        if Nutrient:
            self.df2 = Profile.df[Profile.df.Nutrient.isin(Nutrient)]
            self.df2 = self.df2.reset_index()
       
        if food_type:
            self.df2 = self.df2[self.df2.Veg_Non.isin(food_type)]
            self.df2 = self.df2.reset_index()
      
        if diet:
            for i in range(self.df2.shape[0]):
                l = str(self.df2.loc[i,'Diet']).split()
                
                for d in diet:
                    if d in l:
                        self.df4 = pd.concat([self.df4, self.df2.loc[[i]]], ignore_index=True)
 
        if disease:
            for i in range(self.df2.shape[0]):
                l = str(self.df2.loc[i,'Disease']).split()
                for d in disease:
                    if d in l:
                        self.df5 = pd.concat([self.df5, self.df2.loc[[i]]], ignore_index=True)

        if favorite_food:
            f = self.removestop(favorite_food.split())
            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'Name']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6 = pd.concat([self.df6, Profile.df.loc[[i]]], ignore_index=True)


            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'catagory']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6 = pd.concat([self.df6, Profile.df.loc[[i]]], ignore_index=True)

            
        return self.df2,self.df3,self.df4,self.df5,self.df6
    
    def get_profile(self):
        df2,df3,df4,df5,df6 = self.inputs(self.diet,self.disease,self.nutrient,self.type,self.like)
        
        df_merge = pd.concat([df2,df3,df4,df5,df6],axis=0).drop_duplicates(subset='Name')
        df_merge = df_merge.filter(['Name','Nutrient','Veg_Non','Review'])
        return df_merge

# %%
# multiple inputs by radio button
ob = Profile(['high_protien_diet','gluten_free_diet'],['diabeties','anemia'],
             ['calcium','protien'],['non-veg','veg'],'i like burger and sandwich')

profile = ob.get_profile()
profile
# Out:
#                                                 Name   Nutrient  Veg_Non  \
# 0                     chilli cheese garlic paratha r    calcium      veg
# 1                         grilled norwegian salmon r    calcium  non-veg
# 2                  seared salmon in tabasco butter r    calcium  non-veg
# 4                                cheese baida roti r    calcium      veg
# 5                              masala cheese toast r    calcium      veg
# 6  salmon and avocado tartare passion fruit emuls...    calcium  non-veg
# 7                  choco cookie ice cream sandwich r    protien      veg
# 0               masala chicken egg bhurji sandwich r  vitamin_a  non-veg
# 1                             fried chicken burger r       iron  non-veg
# 2                            chicken mayo sandwich r       iron  non-veg
# 3                   2 ways chicken salami sandwich r       iron  non-veg
# 4                         grilled chicken sandwich r       iron  non-veg
#
#   Review
# 0      3
# 1      4
# 2      6
# 4      7
# 5      3
# 6     10
# 7      9
# 0      2
# 1      5
# 2      2
# 3      8
# 4      8
