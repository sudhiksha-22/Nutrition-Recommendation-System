# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import NearestNeighbors

df = pd.read_csv('dataset.csv')

# %% [markdown]
# Recommendation by K nearest neighbor (Content - based filtering)

# %%
class Recommender:
    
    def __init__(self):
        self.df = pd.read_csv('dataset.csv')
    
    def get_features(self):
        #getting dummies of dataset
        nutrient_dummies = self.df.Nutrient.str.get_dummies()
        disease_dummies = self.df.Disease.str.get_dummies(sep=' ')
        diet_dummies = self.df.Diet.str.get_dummies(sep=' ')
        feature_df = pd.concat([nutrient_dummies,disease_dummies,diet_dummies],axis=1)
     
        return feature_df
    
    def k_neighbor(self,inputs):
        
        feature_df = self.get_features()
        print(len(feature_df.columns))
        #initializing model with k=40 neighbors
        model = NearestNeighbors(n_neighbors=40,algorithm='ball_tree')
        
        # fitting model with dataset features
        model.fit(feature_df)
        
        df_results = pd.DataFrame(columns=list(self.df.columns))
        
      
        # getting distance and indices for k nearest neighbor
        distnaces , indices = model.kneighbors(inputs)

        for i in list(indices):
            df_results = pd.concat([df_results,self.df.loc[i]], ignore_index=True)
        df_results = df_results.filter(['Name','Nutrient','Veg_Non','Review','Diet','Disease'])
        df_results = df_results.drop_duplicates(subset=['Name'])
        df_results = df_results.reset_index(drop=True)
        return df_results

# %% [markdown]
# sample data on which we recommed

# %%
ob = Recommender()
data = ob.get_features()

total_features = data.columns
d = dict()
for i in total_features:
    d[i]= 0
print(d)
# Out:
# {'calcium': 0, 'carbohydrates': 0, 'fiber': 0, 'iron': 0, 'magnesium': 0, 'manganese': 0, 'phosphorus': 0, 'potassium': 0, 'protien': 0, 'selenium': 0, 'vitamin_a': 0, 'vitamin_c': 0, 'vitamin_d': 0, 'vitamin_k': 0, 'anemia': 0, 'cancer': 0, 'diabeties': 0, 'eye_disease': 0, 'goitre': 0, 'heart_disease': 0, 'hypertension': 0, 'kidney_disease': 0, 'obesity': 0, 'pregnancy': 0, 'rickets': 0, 'scurvy': 0, 'alkaline_diet': 0, 'high_fiber_diet': 0, 'high_protien_diet': 0, 'ketogenic_diet': 0, 'low_fat_diet': 0, 'paleo_diet': 0, 'vegan_diet': 0}

# %%
sample_input = ['high_protien_diet','diabeties','anemia','calcium','protien']

for i in sample_input:
    
    d[i] = 1

final_input = list(d.values())

# %% [markdown]
# Results

# %%
results = ob.k_neighbor([final_input]) # pass 2d array []
results
# Out:
# 33
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#                                            Name       Nutrient  Veg_Non  \
# 0                  air fryer aloo corn cutlet r  carbohydrates      veg
# 1                    cheesy paneer cigar roll r     phosphorus      veg
# 2                          methi turmeric tea r      manganese      veg
# 3                            mango bubble tea r      manganese      veg
# 4                         masala cheese toast r        calcium      veg
# 5                               cabbage pulao r      vitamin_k      veg
# 6                           cheese baida roti r        calcium      veg
# 7             choco cookie ice cream sandwich r        protien      veg
# 8                    grilled norwegian salmon r        calcium  non-veg
# 9                          cucumber curd rice r  carbohydrates      veg
# 10               indian style kachumber salad r          fiber      veg
# 11                       nilgiri turkey korma r           iron      veg
# 12                strawberry frozen margarita r      vitamin_c      veg
# 13                      lamb and almond korma r           iron  non-veg
# 14                           millet curd rice r  carbohydrates      veg
# 15            air fryer cheesy malai broccoli r      vitamin_c      veg
# 16                           coorgi ghee rice r  carbohydrates      veg
# 17                           chana palak rice r  carbohydrates      veg
# 18                 paneer schezwan bread roll r     phosphorus      veg
# 19            seared salmon in tabasco butter r        calcium  non-veg
# 20                              cucumber rice r  carbohydrates      veg
# 21                     prawn and litchi salad r          fiber      veg
# 22                  crunchy aloo veggie toast r  carbohydrates      veg
# 23                          samak rice chilla r  carbohydrates      veg
# 24                                 taco salad r          fiber      veg
# 25                          meat lovers pizza r      potassium  non-veg
# 26                          turmeric milk tea r      vitamin_d      veg
# 27  elaneer shake (tender coconut milk shake) r      vitamin_d      veg
# 28     cajun spiced turkey wrapped with bacon r           iron  non-veg
# 29                     eggless banana pancake r       selenium      veg
# 30                               banana kheer r       selenium      veg
# 31                              mango ice tea r      manganese      veg
# 32               chilli cheese garlic paratha r        calcium      veg
# 33                    andhra crab meat masala r      potassium  non-veg
# 34                             roasted turkey r           iron      veg
#
#    Review                                               Diet  \
# 0       6                       high_protien_diet vegan_diet
# 1       6                                         vegan_diet
# 2      10                                     ketogenic_diet
# 3       4                                     ketogenic_diet
# 4       3   alkaline_diet high_fiber_diet high_protien_di...
# 5       4                    high_protien_diet alkaline_diet
# 6       7   alkaline_diet high_fiber_diet high_protien_di...
# 7       9          ketogenic_diet vegan_diet high_fiber_diet
# 8       4   ketogenic_diet high_protien_diet vegan_diet l...
# 9       7        ketogenic_diet high_protien_diet vegan_diet
# 10      8   ketogenic_diet high_protien_diet low_fat_diet...
# 11      1   ketogenic_diet high_protien_diet vegan_diet a...
# 12      4                         vegan_diet high_fiber_diet
# 13      1   alkaline_diet high_fiber_diet high_protien_di...
# 14      2        ketogenic_diet high_protien_diet vegan_diet
# 15      5    high_protien_diet alkaline_diet high_fiber_diet
# 16      7        ketogenic_diet high_protien_diet vegan_diet
# 17      5        ketogenic_diet high_protien_diet vegan_diet
# 18      1                         vegan_diet high_fiber_diet
# 19      6   high_fiber_diet high_protien_diet ketogenic_d...
# 20      7        ketogenic_diet high_protien_diet vegan_diet
# 21      7   ketogenic_diet high_protien_diet low_fat_diet...
# 22      4                       high_protien_diet vegan_diet
# 23      8        ketogenic_diet high_protien_diet vegan_diet
# 24      5   ketogenic_diet high_protien_diet low_fat_diet...
# 25     10        ketogenic_diet high_protien_diet vegan_diet
# 26      9      ketogenic_diet high_protien_diet low_fat_diet
# 27      6      ketogenic_diet high_protien_diet low_fat_diet
# 28      4   ketogenic_diet high_protien_diet vegan_diet a...
# 29      6   ketogenic_diet vegan_diet alkaline_diet high_...
# 30      5   ketogenic_diet vegan_diet alkaline_diet high_...
# 31      8                          ketogenic_diet vegan_diet
# 32      3   alkaline_diet high_fiber_diet high_protien_di...
# 33      6        ketogenic_diet high_protien_diet vegan_diet
# 34      9   alkaline_diet high_fiber_diet high_protien_di...
#
#                                               Disease
# 0                                           diabeties
# 1                                             obesity
# 2                                       heart_disease
# 3                             heart_disease pregnancy
# 4                                             obesity
# 5                       obesity goitre kidney_disease
# 6                                             obesity
# 7                                       goitre cancer
# 8    heart_disease goitre rickets diabeties pregnancy
# 9    heart_disease goitre rickets diabeties kidney...
# 10            rickets diabeties kidney_disease goitre
# 11                                   goitre pregnancy
# 12                                      scurvy goitre
# 13                                             goitre
# 14   heart_disease goitre rickets diabeties kidney...
# 15       obesity goitre scurvy hypertension diabeties
# 16   heart_disease goitre rickets diabeties kidney...
# 17   heart_disease goitre rickets diabeties kidney...
# 18                               scurvy heart_disease
# 19   heart_disease goitre rickets diabeties pregnancy
# 20   heart_disease goitre rickets diabeties kidney...
# 21            rickets diabeties kidney_disease goitre
# 22         hypertension obesity goitre kidney_disease
# 23   heart_disease goitre rickets diabeties kidney...
# 24   goitre rickets diabeties kidney_disease pregn...
# 25   obesity heart_disease hypertension kidney_dis...
# 26        rickets heart_disease cancer kidney_disease
# 27               rickets kidney_disease goitre cancer
# 28                            goitre cancer pregnancy
# 29                                       hypertension
# 30                                       hypertension
# 31                     heart_disease goitre pregnancy
# 32   obesity heart_disease diabeties kidney_diseas...
# 33   obesity heart_disease hypertension kidney_dis...
# 34             kidney_disease anemia goitre pregnancy
