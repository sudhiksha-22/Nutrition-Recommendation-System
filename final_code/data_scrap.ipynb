# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import warnings
import time

# %% [markdown]
# Warnings are ignored

# %%
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_colwidth', None)
class Scrap:
    def __init__(self):
        pass
    
    #content scraping from urls
    def description(self, link):
        url = link
        data = requests.get(url)
        soup = BeautifulSoup(data.content, 'html.parser')
        s = soup.findAll('a', {'class': 'recipe_cont'})  # Find all a elements with class recipe_cont
        links = []
        for i in s:
            links.append(i['href'])  # Append the href attribute to the links list
        print(links)
        description = []
        for link in links:
            url = link
            data = requests.get(url)
            soup = BeautifulSoup(data.content, 'html.parser')
            s = soup.find('div', {'class': 'keyword_tag'})
            try:
                description.append(s.text)
            except:
                description.append(np.nan)
        print(f"Number of descriptions scraped: {len(description)}")
        return description
        
    def healthy(self):
        url = 'https://food.ndtv.com/recipes/healthy-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'}) 
        
        l = []
        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)

        nl = l[-21:]
        ll = []
        for i in nl :        
            ll.append(i[:-6])
        l = l[:-21] + ll 
         
        healthy = pd.DataFrame(columns=['Name','sub_catagory'])
        healthy['Name'] = l
        catagory = ['healthy' for i in range(len(l))]
        healthy['sub_catagory'] = catagory
        return healthy.head(51)

    def snacks(self):
        url = 'https://food.ndtv.com/recipes/snacks-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
     
        nl = l[-21:]
        ll = []
        for i in nl :           
            ll.append(i[:-6])
        l = l[:-21] + ll  
      
        snacks = pd.DataFrame(columns=['Name','catagory'])
        snacks['Name'] = l
        catagory = ['snacks' for i in range(len(l))]
        snacks['sub_catagory'] = catagory
        return snacks.head(51)

    def vegetarian(self):
        url = 'https://food.ndtv.com/recipes/vegetarian-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
   
        nl = l[-21:]
        ll = []
        for i in nl : 
            ll.append(i[:-6])
        l = l[:-21] + ll  
      
        vegetarian = pd.DataFrame(columns=['Name','sub_catagory'])
        vegetarian['Name'] = l
        catagory = ['vegetarian' for i in range(len(l))]
        vegetarian['sub_catagory'] = catagory
        return vegetarian.head(51)
    
    
    def chicken(self):
        url = 'https://food.ndtv.com/recipes/chicken-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        #print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :   
            ll.append(i[:-6])
        l = l[:-21] + ll  
      
        chicken = pd.DataFrame(columns=['Name','catagory'])
        chicken['Name'] = l
        catagory = ['chicken' for i in range(len(l))]
        chicken['sub_catagory'] = catagory
        return chicken.head(51)
    
    def meat(self):
        url = 'https://food.ndtv.com/recipes/meat-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        #print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :
            ll.append(i[:-6])
        l = l[:-21] + ll  
      
        meat = pd.DataFrame(columns=['Name','catagory'])
        meat['Name'] = l
        catagory = ['meat' for i in range(len(l))]
        meat['sub_catagory'] = catagory
        return meat.head(51)

    def seafood(self):
        url = 'https://food.ndtv.com/recipes/seafood-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
      
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        #print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :   
            ll.append(i[:-6])
        l = l[:-21] + ll  
        
        seafood = pd.DataFrame(columns=['Name','sub_catagory'])
        seafood['Name'] = l
        catagory = ['seafood' for i in range(len(l))]
        seafood['sub_catagory'] = catagory
        return seafood.head(51)

    def rice(self):
        url = 'https://food.ndtv.com/recipes/rice-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        #print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :  
            ll.append(i[:-6])
        l = l[:-21] + ll  
    
        rice = pd.DataFrame(columns=['Name','catagory'])
        rice['Name'] = l
        catagory = ['rice' for i in range(len(l))]
        rice['sub_catagory'] = catagory
        return rice.head(51)

    def bread(self):
        url = 'https://food.ndtv.com/recipes/breads-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        #print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :   
            ll.append(i[:-6])
        l = l[:-21] + ll  
      
        bread = pd.DataFrame(columns=['Name','catagory'])
        bread['Name'] = l
        catagory = ['bread' for i in range(len(l))]
        bread['sub_catagory'] = catagory
        return bread.head(51)

    def dinner(self):
        url = 'https://food.ndtv.com/recipes/dinner-party-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
      
        l = []
        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        #print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :    
            ll.append(i[:-6])
        l = l[:-21] + ll  
      

        dinner = pd.DataFrame(columns=['Name','sub_catagory'])
        dinner['Name'] = l
        catagory = ['dinner' for i in range(len(l))]
        dinner['sub_catagory'] = catagory
        return dinner.head(51)

    def beverage(self):
        url = 'https://food.ndtv.com/recipes/beverages-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        # print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :
            ll.append(i[:-6])
        l = l[:-21] + ll  
           
        beverage = pd.DataFrame(columns=['Name','sub_catagory'])
        beverage['Name'] = l
        catagory = ['beverage' for i in range(len(l))]
        beverage['sub_catagory'] = catagory
        return beverage.head(51)

    def breakfast(self):
        url = 'https://food.ndtv.com/recipes/breakfast-recipes'
        data = requests.get(url)
        soup = BeautifulSoup(data.content,'html.parser')
        s = soup.findAll('img',{'class':'lazy'})
        l = []

        for i in s:
            i = str(i)
            t = i.split('title')
            name = t[-1].split('width')[0]
            name = name[2:-8]
            l.append(name)
        # print(l[-22:])
        nl = l[-21:]
        ll = []
        for i in nl :
            ll.append(i[:-6])
        l = l[:-21] + ll  
    
        breakfast = pd.DataFrame(columns=['Name','sub_catagory'])
        breakfast['Name'] = l
        catagory = ['breakfast' for i in range(len(l))]
        breakfast['sub_catagory'] = catagory        
        return breakfast.head(51)
    
    def bringmydata(self):
        df = pd.concat([self.healthy(),self.snacks()],ignore_index=True)
      
        df.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...2nd')
    
    def bringmydata1(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.vegetarian()])
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...3rd')
        
    def bringmydata2(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.beverage()])
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...4th')
        
    def bringmydata3(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.chicken()])
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...5th')
        
    def bringmydata4(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.meat()])
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...6th')
        
    def bringmydata5(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.seafood()])
        
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...7th')
        
    def bringmydata6(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.rice()])
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...8th')
        
    def bringmydata7(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.bread()])
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...9th')
        
    def bringmydata9(self):
        df = pd.read_csv('data.csv')
        df_new = pd.concat([df,self.dinner()])
      
        df_new.to_csv('data.csv')
        df = pd.read_csv('data.csv')
        print(df.shape)
        print('concatenating...11th')
        
    
ob = Scrap()
start = time.process_time()
ob.bringmydata()
ob.bringmydata1()
ob.bringmydata2()
ob.bringmydata3()
ob.bringmydata4()
ob.bringmydata5()
ob.bringmydata6()
ob.bringmydata7()
ob.bringmydata9()
print('time spent in scraping',time.process_time() - start,'seconds')
# Out:
# (102, 4)
# concatenating...2nd
# (153, 5)
# concatenating...3rd
# (204, 6)
# concatenating...4th
# (255, 7)
# concatenating...5th
# (306, 8)
# concatenating...6th
# (357, 9)
# concatenating...7th
# (408, 10)
# concatenating...8th
# (459, 11)
# concatenating...9th
# (510, 12)
# concatenating...11th
# time spent in scraping 1.3630709999999997 seconds
